# %%
# Import packages
# Using Python v3.8.3

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
batters_2021 = "mlb-player-stats-Batters.csv"
batters = pd.read_csv(batters_2021)
batters
# Out:
#                  Player Team Pos  Age    G   AB    R    H  2B  3B  ...  CS  \
# 0       Whit Merrifield   KC  2B   32  162  664   97  184  42   3  ...   4
# 1         Marcus Semien  TOR  2B   31  162  652  115  173  39   2  ...   1
# 2           Tommy Edman  STL  2B   26  159  641   91  168  41   3  ...   5
# 3           Bo Bichette  TOR  SS   23  159  640  121  191  30   1  ...   1
# 4    Isiah Kiner-Falefa  TEX  SS   26  158  635   74  172  25   3  ...   5
# ..                  ...  ...  ..  ...  ...  ...  ...  ...  ..  ..  ...  ..
# 729         Kevin Padlo  SEA  3B   25    1    1    0    0   0   0  ...   0
# 730            Hoy Park  NYY  SS   25    1    1    0    0   0   0  ...   0
# 731           Skye Bolt   SF  OF   28    2    1    0    0   0   0  ...   0
# 732     Tyler Ladendorf  CHC  2B   33    1    1    0    0   0   0  ...   0
# 733     Mario Feliciano  MIL   C   23    1    0    1    0   0   0  ...   0
#
#      BB   SO  SH  SF  HBP    AVG    OBP    SLG    OPS
# ...

# %%
# Describe the data

batters.describe()
# Out:
#               Age           G          AB           R           H          2B  \
# count  734.000000  734.000000  734.000000  734.000000  734.000000  734.000000
# mean    28.651226   68.252044  214.964578   29.708447   53.181199   10.606267
# std      3.615322   49.276905  180.919310   28.595442   49.273590   10.327463
# min     20.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     26.000000   23.000000   51.250000    6.000000   10.000000    2.000000
# 50%     28.000000   60.000000  174.500000   21.000000   39.000000    8.000000
# 75%     31.000000  110.750000  338.000000   47.000000   85.750000   17.000000
# max     41.000000  162.000000  664.000000  123.000000  191.000000   42.000000
#
#                3B          HR         RBI          SB          CS          BB  \
# count  734.000000  734.000000  734.000000  734.000000  734.000000  734.000000
# mean     0.912807    8.079019   28.374659    3.009537    0.967302   21.277929
# ...

# %%
batters.columns
# Out:
# Index(['Player', 'Team', 'Pos', 'Age', 'G', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'SH', 'SF', 'HBP', 'AVG', 'OBP', 'SLG',
#        'OPS'],
#       dtype='object')

# %%
# Get values: total batters, mean AB, mean H, mean BA

batct = 0
for x in batters["Player"]:
    batct += 1
batct
# Out:
# 734

# %%
# mean_ab = batters["AB"].mean()
# mean_ab

sum_ab = batters["AB"].sum()
sum_ab
# Out:
# 157784

# %%
mean_h = batters["H"].mean()
mean_h
# Out:
# 53.18119891008175

# %%
mean_ba = batters.H.sum()/batters.AB.sum()
mean_ba
# Out:
# 0.2473951731481012

# %%
batters.AB.sum()
# Out:
# 157784

# %%
batters.H.sum()
# Out:
# 39035

# %%
plt.scatter(batters.H, batters.AB)
plt.show()
